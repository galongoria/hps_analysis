# %%
import pandas as pd
import os

# %%
IN_FILE_PATH = os.path.join("invoices_xl", "Invoice_ABlumrosen_821.xlsx")
DIR_PATH = os.path.join("invoices_xl")
OUT_FILE = "clean_data_322.csv"
OUT_DIR = os.path.join("hps")
OUT_PATH = os.path.join(OUT_DIR, OUT_FILE)

# %%
# pd.read_excel(IN_FILE_PATH)


def data_cleaner(directory):
    
    df = pd.DataFrame()
    i = 0
    read = True
    
    for filename in os.listdir(directory):
        d = pd.read_excel(os.path.join(directory, filename))
        
        for index, row in d.iterrows():
            if row[1] == "TOTAL":
                df.loc[i, "amount"] = row[2]
        df.loc[i, "name"]= d.iloc[9][0]
        df.loc[i, "address"] = d.iloc[10][0]
        df.loc[i, "csz"] = d.iloc[11][0]
        df.loc[i, "number"] = d.iloc[12][0]
        df.loc[i, "email"] = d.iloc[13][0]
        df.loc[i, "date"] = d.iloc[2][2]
        df.loc[i, "invoice_num"] = d.iloc[3][2]
        
        i += 1


    
    return df



if __name__ == "__main__":
    os.makedirs(OUT_DIR, exist_ok=True)
    clean_data = data_cleaner(IN_FILE_PATH)
# Out:
# C:\Users\galon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\galon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df
# Out:
#       amount                   name                  address  \
# 0     659.99          Amy Blumrosen      5111 Longmont Drive
# 1     197.00     Annette Boatwright     10015 Longmont Drive
# 2     491.00          Angie Collins             26 Shadow Ln
# 3     517.00          Angie Collins      10030 Bayou Glen Rd
# 4     725.00          Angie Collins             10834 Alcott
# ..       ...                    ...                      ...
# 688  1394.00      Hettig Management    5325 Katy Fwy #1 & #2
# 689   747.00           Tom Wimberly  1244 Ripple Creek Drive
# 690  1490.00          William Smith         342 West 21st St
# 691  1250.00          William Smith         342 West 21st St
# 692   687.00  Cindy Florio-Youschak  13823 Nueces Springs Ln
#
#                      csz          number                      email  \
# 0      Houston, TX 77056    7133743564.0                        NaN
# 1      Houston, TX 77042    7132537370.0                        NaN
# 2      Houston, TX 77080  (713) 201-8376                        NaN
# 3    Houston, TX , 77042      7132018376  Angiewcollins@comcast.net
# 4      Houston, TX 77043      7132018376                        NaN
# ..                   ...             ...                        ...
# 688    Houston, TX 77007             NaN                        NaN
# 689    Houston, TX 77057      2817481962                        NaN
# 690    Houston, TX 77008      8327719354                        NaN
# 691  Houston, TX , 77008      8327719354         wjsmith123@aol.com
# 692    Cypress, TX 77429  (713) 453-8328                        NaN
#
#                     date invoice_num
# 0    2021-09-01 00:00:00    00210901
# 1    2021-09-08 00:00:00    03210908
# 2    2020-10-20 00:00:00    00201020
# 3    2021-10-28 00:00:00    03211028
# 4    2020-11-17 00:00:00    01201117
# ..                   ...         ...
# 688  2020-07-23 00:00:00    03200723
# 689  2021-05-27 00:00:00    01210527
# 690  2021-08-26 00:00:00    00210826
# 691  2021-09-23 00:00:00    01210923
# 692  2020-07-07 00:00:00    03200707
#
# [693 rows x 8 columns]

# %%
df[df["amount"].isnull()]
# Out:
#      amount                            name  \
# 70      NaN                         Ed Capo
# 202  (713) 907-0414   NaN  2020-10-19 00:00:00    01201019
# 237      8323738093   NaN  2020-09-09 00:00:00    00200909
# 250      7134124368   NaN  2021-04-28 00:00:00    00210428
# 318             NaN   NaN  2021-01-26 00:00:00    01210126
# 322             NaN   NaN  2021-05-12 00:00:00    05210512
# 326             NaN   NaN  2021-05-07 00:00:00    00210507
# 346      7135452674   NaN  2020-11-09 00:00:00    00201109
# 347      7135452674   NaN  2020-11-09 00:00:00    00201109
# 357      8329783576   NaN  2020-10-23 00:00:00    01201023
# 376      2816108154   NaN  2020-09-16 00:00:00    00200916
# 411      8323738093   NaN  2020-09-08 00:00:00    01200908
# 421      8327818903   NaN  2020-09-28 00:00:00    00200928
# 532  (832) 202-8975   NaN  2020-08-25 00:00:00    07200825
# 553             NaN   NaN  2021-01-07 00:00:00    01210107
# 554             NaN   NaN  2021-01-07 00:00:00    00210107
# 559  (281) 457-2800   NaN  2020-07-20 00:00:00    00200720
# 560  (281) 457-2800   NaN  2020-07-16 00:00:00    00200716
# 562      2816675899   NaN  2020-09-04 00:00:00    01200904
# 611  (713) 501-1656   NaN  2020-07-15 00:00:00    01200715
# 659      8326619678   NaN  2020-10-05 00:00:00    00201005
# 671      2818909525   NaN  2020-09-14 00:00:00    00200914
# 672      2818909525   NaN  2020-09-11 00:00:00    01200911
# 680      7137054881   NaN  2021-05-05 00:00:00    01210505

# %%
os.getcwd()
# Out:
# 'C:\\Users\\galon\\hps'

# %%
pd.read_excel(os.path.join("invoices_xl" , "Invoice_Capo_321.xlsx"))
# Out:
#                                  Houston Power Savers    INVOICE  \
# 0                                        TACLB020326E        NaN
# 1                                                 NaN        NaN
# 2                                     10222 Inwood Dr      DATE:
# 3                                 Houston,Texas 77042  INVOICE #
# 4                              Office: (832) 968-0000       FOR:
# 5                          www.HoustonPowerSavers.com        NaN
# 6                                                 NaN        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                             Ed Capo        NaN
# 10                               10411 Londonderry Dr        NaN
# 11                                  Houston, TX 77043        NaN
# 12                                     (832) 294-8945        NaN
# 13                                                NaN        NaN
# 14                                                NaN        NaN
# 15                                        DESCRIPTION        NaN
# 16                                     Inspection fee        NaN
# 17                                           subtotal        NaN
# 18                                                NaN        NaN
# 19                                                NaN        NaN
# 20                                                NaN        NaN
# 21                                                NaN        NaN
# 22                                                NaN        NaN
# 23                                                NaN        NaN
# 24                                                NaN        NaN
# 25                                                NaN        NaN
# 26                                                NaN        NaN
# 27                                                NaN        NaN
# 28                                                NaN        NaN
# 29                                                NaN        NaN
# 30                                                NaN        NaN
# 31                                                NaN        NaN
# 32                                                NaN        NaN
# 33                                                NaN      TOTAL
# 34                                                NaN        NaN
# 35                                                NaN        NaN
# 36    Make all checks payable to Houston Power Savers        NaN
# 37  If you have any questions concerning this invo...        NaN
# 38                                                NaN        NaN
# 39                                                NaN        NaN
# 40                      THANK YOU FOR YOUR BUSINESS!         NaN
#
#              Unnamed: 2
# 0                   NaN
# 1                   NaN
# 2   2021-03-23 00:00:00
# 3              05210323
# 4    Service/maintenace
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15               AMOUNT
# 16                  NaN
# 17                  200
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  200
# 34                  NaN
# 35                  NaN
# 36                  NaN
# 37                  NaN
# 38                  NaN
# 39                  NaN
# 40                  NaN

# %%
s.iloc[3][2]
# Out:
# '01210708'
