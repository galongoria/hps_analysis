# %%
import pandas as pd
import os

# %%
IN_FILE_PATH = os.path.join("../data", "invoices_xl")
OUT_FILE = "clean_data_322.csv"
OUT_DIR = os.path.join("../data")
OUT_PATH = os.path.join(OUT_DIR, OUT_FILE)

# %%
def invoice_to_df(directory):
    df = pd.DataFrame()
    i = 0
    read = True    
    for filename in os.listdir(directory):
        d = pd.read_excel(os.path.join(directory, filename))       
        for index, row in d.iterrows():
            if row[1] == "TOTAL":
                df.loc[i, "amount"] = row[2]
        df.loc[i, "name"]= d.iloc[9][0]
        df.loc[i, "address"] = d.iloc[10][0]
        df.loc[i, "csz"] = d.iloc[11][0]
        df.loc[i, "number"] = d.iloc[12][0]
        df.loc[i, "email"] = d.iloc[13][0]
        df.loc[i, "date"] = d.iloc[2][2]
        df.loc[i, "invoice_num"] = d.iloc[3][2]
        i += 1
    return df



if __name__ == "__main__":
    os.makedirs(OUT_DIR, exist_ok=True)
    clean_data = data_cleaner(IN_FILE_PATH)
    clean_data.to_csv(OUT_PATH, index = False)
# Out:
# C:\Users\galon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\galon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\galon\\hps\\code'

# %%
# pd.read_excel(os.path.join("invoices_xl" , "Invoice_Capo_321.xlsx"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 2>()
#       1 # pd.read_excel(os.path.join("invoices_xl" , "Invoice_Capo_321.xlsx"))
# ----> 2 clear
#
# NameError: name 'clear' is not defined

# %%
def invoice_to_df(directory):
    df = pd.DataFrame()
    i = 0
    read = True    
    for filename in os.listdir(directory):
        d = pd.read_excel(os.path.join(directory, filename))       
        for index, row in d.iterrows():
            if row[1] == "TOTAL":
                df.loc[i, "amount"] = row[2]
        df.loc[i, "name"]= d.iloc[9][0]
        df.loc[i, "address"] = d.iloc[10][0]
        df.loc[i, "csz"] = d.iloc[11][0]
        df.loc[i, "number"] = d.iloc[12][0]
        df.loc[i, "email"] = d.iloc[13][0]
        df.loc[i, "date"] = d.iloc[2][2]
        df.loc[i, "invoice_num"] = d.iloc[3][2]
        i += 1
    return df

df = invoice_to_df(IN_FILE_PATH)
df.head(20)
# Out:
# C:\Users\galon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# C:\Users\galon\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#      amount                    name               address  \
# 0    659.99           Amy Blumrosen   5111 Longmont Drive
# 1    197.00      Annette Boatwright  10015 Longmont Drive
# 2    491.00           Angie Collins          26 Shadow Ln
# 3    517.00           Angie Collins   10030 Bayou Glen Rd
# 4    725.00           Angie Collins          10834 Alcott
# 5    551.76       Angie Collins (A)          10834 Alcott
# 6    291.00       Angie Collins (A)          10834 Alcott
# 7    297.00       Angie Collins (s)          26 Shadow Ln
# 8   1018.00           Angie Collins          26 Shadow Ln
# 9    688.00           Angie Collins          10834 Alcott
# 10  2775.00             Abel Garcia        4418 Austin St
# 11  2475.00             Abel Garcia        4418 Austin St
# 12   294.00              Alicia Lee        10043 Locke Ln
# 13  1975.00             John Allred       10027 Inwood Dr
# 14   247.00             John Allred       10027 Inwood Dr
# 15   197.00  Almeda Park Apartments  10950 Tanner Park Ct
# 16   750.00             Amy McGuire         6919 Mobud Dr
# 17   444.00             Amy McGuire         6919 Mobud Dr
# 18   697.00             Amy McGuire         6919 Mobud Dr
# 19   597.00             Amy McGuire         6919 Mobud Dr
#
#                     csz          number                        email  \
# 0     Houston, TX 77056    7133743564.0                          NaN
# 1     Houston, TX 77042    7132537370.0                          NaN
# 2     Houston, TX 77080  (713) 201-8376                          NaN
# 3   Houston, TX , 77042      7132018376    Angiewcollins@comcast.net
# 4     Houston, TX 77043      7132018376                          NaN
# 5   Houston,  TX  77043      7132018376    Angiewcollins@comcast.net
# 6   Houston,  TX  77043      7132018376    Angiewcollins@comcast.net
# 7   Houston,  TX  77080      7132018376    Angiewcollins@comcast.net
# 8     Houston, TX 77042      7132018376                          NaN
# 9     Houston, TX 77042      7132018376                          NaN
# 10    Houston, TX 77004      9792155535                          NaN
# 11    Houston, TX 77004      9792155535                          NaN
# 12    Houston, TX 77042      7138283798                          NaN
# 13    Houston, TX 77042      2813898832                          NaN
# 14    Houston, TX 77042      2813898832                          NaN
# 15    Houston, TX 77075      7139441131                          NaN
# 16  Houston,  TX  77074      8324837637  ameliamcguire@sbcglobal.net
# 17  Houston,  TX  77074      8324837637  ameliamcguire@sbcglobal.net
# 18    Houston, TX 77074      8324837637                          NaN
# 19    Houston, TX 77074      8324837637                          NaN
#
#                    date invoice_num
# 0   2021-09-01 00:00:00    00210901
# 1   2021-09-08 00:00:00    03210908
# 2   2020-10-20 00:00:00    00201020
# 3   2021-10-28 00:00:00    03211028
# 4   2020-11-17 00:00:00    01201117
# 5   2022-02-01 00:00:00    00220126
# 6   2022-01-13 00:00:00    03220113
# 7   2022-02-16 00:00:00    00220214
# 8   2021-06-17 00:00:00    03210617
# 9   2021-07-09 00:00:00    02210709
# 10  2021-07-08 00:00:00    01210708
# 11  2021-07-06 00:00:00    01210708
# 12  2020-08-25 00:00:00    03200825
# 13  2020-10-19 00:00:00    02201019
# 14  2021-06-14 00:00:00    00210614
# 15  2020-09-03 00:00:00    01200903
# 16  2021-12-21 00:00:00    01211221
# 17  2022-02-22 00:00:00    00220222
# 18  2021-06-08 00:00:00    00210608
# 19  2021-06-08 00:00:00    00210608

# %%
def clean_df(df):
    read = True
    i = 0
    for index, row in df.iterrows():
        if read == True:
            df.loc[i, "daily_ct"] = str(row[7])[0:2]
            df.loc[i, "day"] = str(row[7])[6:]
            df.loc[i, "month"] = str(row[7])[4:6]
            df.loc[i, "year"] = str(row[7])[2:4]
            i +=1
    return df





data = clean_df(df)
# Out:
#       amount                   name                  address  \
# 0     659.99          Amy Blumrosen      5111 Longmont Drive
# 1     197.00     Annette Boatwright     10015 Longmont Drive
# 2     491.00          Angie Collins             26 Shadow Ln
# 3     517.00          Angie Collins      10030 Bayou Glen Rd
# 4     725.00          Angie Collins             10834 Alcott
# ..       ...                    ...                      ...
# 689  1394.00      Hettig Management    5325 Katy Fwy #1 & #2
# 690   747.00           Tom Wimberly  1244 Ripple Creek Drive
# 691  1490.00          William Smith         342 West 21st St
# 692  1250.00          William Smith         342 West 21st St
# 693   687.00  Cindy Florio-Youschak  13823 Nueces Springs Ln
#
#                      csz          number                      email  \
# 0      Houston, TX 77056    7133743564.0                        NaN
# 1      Houston, TX 77042    7132537370.0                        NaN
# 2      Houston, TX 77080  (713) 201-8376                        NaN
# 3    Houston, TX , 77042      7132018376  Angiewcollins@comcast.net
# 4      Houston, TX 77043      7132018376                        NaN
# ..                   ...             ...                        ...
# 689    Houston, TX 77007             NaN                        NaN
# 690    Houston, TX 77057      2817481962                        NaN
# 691    Houston, TX 77008      8327719354                        NaN
# 692  Houston, TX , 77008      8327719354         wjsmith123@aol.com
# 693    Cypress, TX 77429  (713) 453-8328                        NaN
#
#                     date invoice_num daily_ct day month year
# 0    2021-09-01 00:00:00    00210901       00  01    09   21
# 1    2021-09-08 00:00:00    03210908       03  08    09   21
# 2    2020-10-20 00:00:00    00201020       00  20    10   20
# 3    2021-10-28 00:00:00    03211028       03  28    10   21
# 4    2020-11-17 00:00:00    01201117       01  17    11   20
# ..                   ...         ...      ...  ..   ...  ...
# 689  2020-07-23 00:00:00    03200723       03  23    07   20
# 690  2021-05-27 00:00:00    01210527       01  27    05   21
# 691  2021-08-26 00:00:00    00210826       00  26    08   21
# 692  2021-09-23 00:00:00    01210923       01  23    09   21
# 693  2020-07-07 00:00:00    03200707       03  07    07   20
#
# [694 rows x 12 columns]

# %%
pd.to_datetime(data[["day", "month", "year"]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "n"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 pd.to_datetime(data[["day", "month", "year"]])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\tools\datetimes.py:1054, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1054     result = _assemble_from_unit_mappings(arg, errors, tz)
#    1055 elif isinstance(arg, Index):
#    1056     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\tools\datetimes.py:1183, in _assemble_from_unit_mappings(arg, errors, tz)
#    1179         values = values.astype("int64", copy=False)
#    1180     return values
#    1182 values = (
# -> 1183     coerce(arg[unit_rev["year"]]) * 10000
#    1184     + coerce(arg[unit_rev["month"]]) * 100
#    1185     + coerce(arg[unit_rev["day"]])
#    1186 )
#    1187 try:
#    1188     values = to_datetime(values, format="%Y%m%d", errors=errors, utc=tz)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\tools\datetimes.py:1175, in _assemble_from_unit_mappings.<locals>.coerce(values)
#    1173 def coerce(values):
#    1174     # we allow coercion to if errors allows
# -> 1175     values = to_numeric(values, errors=errors)
#    1177     # prevent overflow in case of int8 or int16
#    1178     if is_integer_dtype(values):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\tools\numeric.py:184, in to_numeric(arg, errors, downcast)
#     182 coerce_numeric = errors not in ("ignore", "raise")
#     183 try:
# --> 184     values, _ = lib.maybe_convert_numeric(
#     185         values, set(), coerce_numeric=coerce_numeric
#     186     )
#     187 except (ValueError, TypeError):
#     188     if errors == "raise":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\_libs\lib.pyx:2357, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "n" at position 67

# %%
df["date"].str.split(" ",n=1,expand=True)
# Out:
#        0
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 689  NaN
# 690  NaN
# 691  NaN
# 692  NaN
# 693  NaN
#
# [694 rows x 1 columns]
